# %%
#setup, include=F

knitr::opts_chunk$set(echo = F)
options(scipen = 10)
library(tidyverse)
library(knitr)
library(kableExtra)
library(gridExtra)
library(binom)
library(gplots)
library(FactoMineR)
library(lattice)
library(tidyverse)
library(ca)

#library(latex2exp)
